# %%
x = input()
if x.isupper() :
   print(x.islower())
elif x.lower : 
   print(x.upper())
else:
   print(10)
# Out:
# S

# %%
c = input("")
if c.isalpha():
    print(f"{c} là kí tự alphabet")
else:
    print(f"{c} không phải là kí tự alphabet")
# Out:
# h là kí tự alphabet

# %%
a = int(input())
b = int(input())
if a > b:
    print(a)
elif b > a:
    print(b)
else:
    print("a=b")
# Out:
# 10

# %%
c = input("")
if c.isalpha():
    print(c)
elif c.isdigit():
    print(c)
else:
    print("Đây không phải là chữ cái hay chữ số.")
# Out:
# 5

# %%
a = int(input())
if a >= 8:
    print("gioi")
elif  8>= a >= 6.5:
    print("kha")
elif 6.5>=a>=5:
    print("TB")
else:
    print("yeu")
# Out:
# kha

# %%
a = int(input())
if a%400 == 0 or a%4 == 0 and a%100 != 0:
    print("la nam nhuan hihi")
else:
    print("k phai nha bro")
# Out:
# k phai nha bro

# %%
c = input("")
if c.isupper():
    if c == 'A':
        print("A")
    else:
        lower_char = c.lower()
        previous_char = chr(ord(lower_char) - 1)
        print(f"Chữ cái thường liền trước là: {previous_char}")
else:
    print("Ký tự nhập vào không phải là chữ hoa.")
# Out:
# Ký tự nhập vào không phải là chữ hoa.

# %%
a = int(input())
match a:
    case 0:
        print("khong")
    case 1:
        print("mot")
    case 2:
        print("hai")
    case 3:
        print("ba")
    case 4:
        print("bon")
    case 5:
        print("nam")
    case 6:
        print("sau")
    case 7:
        print("bay")
    case 8:
        print("Tam")
    case 9:
        print("chin")
    case _:
        print("loi")
# Out:
# nam

# %%
a = int(input())
if a >= 4:
   print("qua mon")
else:
   print("truot r hoc lai di")
# Out:
# truot r hoc lai di

# %%
nay = int(input())
sinh = int(input())
tuoi = nay-sinh
if tuoi >= 18:
    print("18 tuoi r hahahaha")
else:
    print("tre con chua 18 tuoi le")
# Out:
# 18 tuoi r hahahaha

# %%
a = int(input(""))
b = int(input(""))
c = int(input(""))
if a+b>c and b+c>a and a+c>b :
    p = (a+b+c)/2
    s = (p*(p-a)*(p-b)*(p-c))**0.5
    print("dien tich ram giac : {:.1f}".format(s))
else :
    print("k phai tam giac")
# Out:
# dien tich ram giac : 9.9

# %%
n = int(input(5))
a = n*2
print(a)
# Out:
# 10

# %%
a = int(input(5))
b = int(input(4))
c = 3.14*a
print("dien tich {:.2f}".format(c))
# Out:
# dien tich 15.70

# %%
x = input()
if len(x) >= 20:
    print(x[4])
    print(x[8])
else:
    print("sai r hihihihih")
# Out:
# 5
# 4

# %%
ten = input("")
cu = int(input())
moi = int(input())
dien = moi-cu
if dien <= 50:
   tien = dien*1984
elif 51 <= dien <= 100:
   tien = dien*2050
elif 101 <= dien <= 200:
   tien = dien*2380
elif 201<= dien <= 300:
   tien = dien*2998
elif 301 <= dien <= 400:
   tien = dien*3350
else:
   tien = dien*3460
tien_phai_tra = round(tien*108/100)
print(ten)
print(tien_phai_tra)
# Out:
# Nguyen Xuan Hai
# 465242

# %%
ten = input("")
cu = int(input())
moi = int(input())
dien = moi-cu
if dien <= 50:
   tien = dien*1984
elif 51 <= dien <= 100:
   tien = dien*2050
elif 101 <= dien <= 200:
   tien = dien*2380
elif 201<= dien <= 300:
   tien = dien*2998
elif 301 <= dien <= 400:
   tien = dien*3350
else:
   tien = dien*3460
tien_phai_tra = round(tien*108/100)
print(ten)
print(tien_phai_tra)
# Out:
# Pham Xuan Toai
# 107136

# %%
ten = input("")
cu = int(input())
moi = int(input())
dien = moi-cu
if dien <= 50:
   tien = dien*1984
elif 51 <= dien <= 100:
   tien = dien*2050
elif 101 <= dien <= 200:
   tien = dien*2380
elif 201<= dien <= 300:
   tien = dien*2998
elif 301 <= dien <= 400:
   tien = dien*3350
else:
   tien = dien*3460
tien_phai_tra = round(tien*108/100)
print(ten)
print(tien_phai_tra)
# Out:
# Nguyen Xuan long
# 2189765

# %%
a = int(input())
if a%2 == 0:
  print(a)
else:
  print("sai r")
# Out:
# 6

# %%
a = int(input())
if a%10 == 5:
    print("true")
else:
    print("false")
# Out:
# true

# %%
a = int(input())
if a%3 ==0 and a%5 ==0:
    print("true")
else:
    print("false")
# Out:
# false

# %%
sinh = int(input())
tai = int(input())
if tai - sinh >=18:
    print("du tuoi bau cu")
else:
    print("k du tuoi bau cu")
# Out:
# du tuoi bau cu
