# %%
#bai 1
a, b = map(float, input().split())
print(f"dien tich : {a*b}")
print(f"chu vi : {2*(a*b)}")
# Out:
# dien tich : 20.0
# chu vi : 40.0

# %%
#bai 2
import math
a = float(input())
print(f"dien tich : {math.pi*(a**2)}")
# Out:
# dien tich : 50.26548245743669

# %%
a, b, c = map(float, input().split())
if a+b<=c or a+c<=b or b+c<=a:
    print("khong phai la 3 canh tam giac")
elif a==b or b==c or a==c:
    print("la tam giac can")
elif a==b and a==c and b==c:
    print("la tam giac deu")
elif a**2==b**2 + c**2 or b**2==a**2 + c**2 or c**2== a**2+b**2 :
    print("la tam giac vuong")
else:
    print("la tam giac thuong")
P=a+b+c
p=P/2
S=math.sqrt(p*(p-a)*(p-b)*(p-c))
print(f"chu vi:{P}")
print(f"diện tích:{S}")
# Out:
# la tam giac thuong
# chu vi:18.0
# diện tích:14.696938456699069

# %%
a, b = map(float, input().split())
print("giải hệ phương trình : a*x+b=0")
if a==0:
    if b==0:
        print("phuong trinh vo so nghiem")
    else:
        print("phuong trinh vo nghiem")
else:
    x=-b/a
    print(f"nghiem cua phuong trinh x=:{x}")
# Out:
# giải hệ phương trình : a*x+b
# nghiem cua phuong trinh x=:-1.2

# %%
import math
a, b, c = map(float, input().split())
d= b**2 - 4*a*c
if d<0:
    print("phuong trinh vo nghiem")
elif d==0:
    print(f"phuong trinh co nghhiem kep x= {-b/2**a}")
else:
    print("phuong trinh co 2 nghiem phan biet")
    print(f"x1=(-b + math.sqrt d)/2*a")
    print(f"x2=(-b -math.sqrt d)/2*a")
# Out:
# phuong trinh vo nghiem

# %%
a, b, c, d = input("").split()
gtln= max(a, b, c ,d)
print(f"gia tri lon nhat:{gtln}")
# Out:
# gia tri lon nhat:7

# %%
a, b, c, d = input("").split()
gtnn= min(a, b, c ,d)
print(f"gia tri lon nhat:{gtnn}")
# Out:
# gia tri lon nhat:1

# %%
a,b,c,d,m,n =map(float, input().split())
det=a*d-b*c
if det==0:
    print("he phuong trinh vo nghiem duy nhat")
else:
    print(f"x:{m*d-n*b}")
    print(f"y:{a*n-c*m}")
# Out:
# x:19.0
# y:-20.0

# %%
a = float(input())
p = a*60
h = a*3600 
g = a + p
print(f"{p} phut {h} gio {a} giay")
# Out:
# 300.0 phut 18000.0 gio 5.0 giay

# %%
x0,y0,x1,y1,r=map(float, input().split())
if (x1-x0)**2+(y1-y0)**2==r**2:
    print("diem nam tren duong tron")
else:
    print("diem nam ngoai duong tron")
# Out:
# diem nam ngoai duong tron

# %%
x, y = map(float, input().split())
t= x**y
print(t)
# Out:
# 625.0
