# %%
a, b, c = map(float, input().split())
tquan = a*10
tao = b*23
tdo = c*12
tong = a*10 + b*23 + c*12
if a == 0 and b == 0 and c == 0:
    print("ngheo")
else:
    print(" tien quan: ", tquan)
    print(" tien ao: ", tao)
    print(" tien do: ", tdo)
    print("tong tien: ", tong)
# Out:
#  tien quan:  30.0
#  tien ao:  92.0
#  tien do:  60.0
# tong tien:  182.0

# %%
a, b, c, d = map(float, input().split())

# %%
a=0
if a==0:
   b= a+1
print(b)
