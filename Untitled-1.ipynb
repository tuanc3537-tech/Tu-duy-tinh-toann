# %% [markdown]
# a = 7
# → Dòng này gán giá trị 7 cho biến a.
# Sau khi thực hiện, ta có:
# a = 7
#
#
#
# b = 5
# → Gán giá trị 5 cho biến b.
# Bây giờ:
# a = 7
# b = 5
#
#
#
# c = a - b
# → Thực hiện phép trừ giữa a và b:
# c = 7 - 5
#
# → Kết quả là 2, nên biến c nhận giá trị 2.
#
#
# print(c)
# → In ra giá trị của c ra màn hình.
# Kết quả hiển thị sẽ là:
# 2
#
#
#
#
# ✅ Kết luận:
#
#
# Đoạn code tính hiệu giữa hai số 7 và 5, rồi in ra kết quả.
#
#
# Kết quả in ra: 2.
#
#
#
# Thực thi thử đoạn code:
# Khi chạy đoạn code trên trong Python, kết quả thực tế sẽ là:
# 2
#
# → Kết quả đúng như phân tích lý thuyết.

# %%
a = 7 
b = 5 
c = a - b 
print(c)
# Out:
# 2

# %% [markdown]
# city = "Hà Nội"
# → Dòng này gán chuỗi ký tự "Hà Nội" cho biến city.
# Sau khi thực hiện:
#
# city = "Hà Nội"
#
#
# year = 2025
# → Gán giá trị số nguyên 2025 cho biến year.
# Bây giờ:
#
# city = "Hà Nội"
# year = 2025
#
#
# print("Thành phố: ", city, " - Năm: ", year)
# → Hàm print() dùng để in ra màn hình.
#
# Trong dấu ngoặc, các phần được ngăn cách bởi dấu phẩy (,).
#
# Khi dùng dấu phẩy, Python sẽ tự thêm một khoảng trắng giữa các phần.
# → Vì vậy, câu lệnh trên sẽ ghép chuỗi như sau:
#
# "Thành phố: " + " " + "Hà Nội" + " " + "- Năm: " + " " + "2025"
#
# Kết quả in ra trên màn hình:
# Thành phố:  Hà Nội  - Năm:  2025

# %%
city = "Hà Nội"
year = 2025
print("Thành phố: ", city, " - Năm: ", year)
# Out:
# Thành phố:  Hà Nội  - Năm:  2025

# %% [markdown]
# n = 4
# → Gán giá trị 4 cho biến n.
# Biến này đại diện cho giới hạn trên của dãy số cần cộng (từ 1 đến 4).
#
# t = 0
# → Gán giá trị 0 cho biến t.
# Biến t được dùng để lưu tổng tạm thời.
#
# for i in range(1, n+1):
# → Tạo một vòng lặp với biến i lần lượt nhận các giá trị từ 1 đến n (bao gồm n).
# Vì range(1, n+1) nghĩa là:
#
# i = 1, 2, 3, 4
#
#
# t += i
# → Mỗi lần lặp, cộng giá trị i vào biến t.
# Có thể hiểu là:
#
# t = t + i
#
#
# Ta theo dõi từng bước:
#
# Lần lặp	i	t (sau khi cộng)
# 1	1	0 + 1 = 1
# 2	2	1 + 2 = 3
# 3	3	3 + 3 = 6
# 4	4	6 + 4 = 10
#
# Sau khi vòng lặp kết thúc, t = 10.
#
# print(t)
# → In ra kết quả cuối cùng của tổng.
#
# Kết quả in ra:
# 10
#
# ✅ Kết luận:
#
# Đoạn code tính tổng các số tự nhiên từ 1 đến 4.
#
# Kết quả thu được là:

# %%
n = 4
t = 0
for i in range(1, n+1):
t += i
print(t)
# Out:
#   Cell In[4], line 4
#     t += i
#     ^
# IndentationError: expected an indented block after 'for' statement on line 3

# %% [markdown]
# numbers = [1, 2, 3, 4]
# → Dòng này tạo một danh sách (list) gồm các phần tử [1, 2, 3, 4]
# Biến numbers chứa bốn số nguyên: 1, 2, 3, và 4.
#
# for x in numbers:
# → Dòng này tạo vòng lặp for, trong đó biến x lần lượt nhận từng giá trị trong danh sách numbers.
# Nghĩa là:
#
# Lần 1: x = 1
# Lần 2: x = 2
# Lần 3: x = 3
# Lần 4: x = 4
#
#
# if x % 2 == 0:
# → Dòng này kiểm tra phép chia dư (% là toán tử chia lấy dư).
#
# Nếu x % 2 == 0 nghĩa là x chia hết cho 2, tức là số chẵn.
#
# Ngược lại, nếu không chia hết cho 2 → số lẻ.
#
# print(x, "là số chẵn")
# → Nếu điều kiện x % 2 == 0 đúng, in ra dòng:
#
# [giá trị của x] là số chẵn
#
#
# else:
# → Trường hợp ngược lại (khi x không chia hết cho 2).
#
# print(x, "là số lẻ")
# → In ra dòng:
#
# [giá trị của x] là số lẻ
#
# Kết quả từng vòng lặp:
# Lần lặp	x	Kiểm tra	Kết quả in ra
# 1	1	1 % 2 = 1 ≠ 0	1 là số lẻ
# 2	2	2 % 2 = 0	2 là số chẵn
# 3	3	3 % 2 = 1 ≠ 0	3 là số lẻ
# 4	4	4 % 2 = 0	4 là số chẵn
# ✅ Kết quả in ra cuối cùng:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn
#
# Khi thực thi trong Python
#
# → Kết quả thực tế đúng hoàn toàn như phân tích trên:
#
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %%
numbers = [1, 2, 3, 4]
for x in numbers:
    if x%2 == 0:
        print(x, "là số chẵn")
    else:
        print(x, "là số lẻ ")
# Out:
# 1 là số lẻ
# 2 là số chẵn
# 3 là số lẻ
# 4 là số chẵn

# %% [markdown]
# animals = ["cat", "dog", "cat", "bird"]
# → Dòng này tạo một danh sách (list) gồm 4 phần tử là các chuỗi ký tự:
# ["cat", "dog", "cat", "bird"]
#
# Biến animals sẽ chứa danh sách này.
#
#
#
#
#
# count = 0
# → Khởi tạo biến đếm count bằng 0.
# Biến này sẽ được dùng để đếm số phần tử trong danh sách animals.
#
#
#
#
#
# for a in animals:
# → Bắt đầu vòng lặp for, trong đó biến a sẽ lần lượt nhận từng phần tử trong danh sách animals.
# Nghĩa là:
# Lần 1: a = "cat"
# Lần 2: a = "dog"
# Lần 3: a = "cat"
# Lần 4: a = "bird"
#
#
#
#
#
#
# count += 1
# → Mỗi lần lặp, biến count tăng thêm 1.
# Có thể hiểu là:
# count = count + 1
#
# Diễn biến từng bước:
# Lần lặpa (phần tử hiện tại)count sau khi cộng1"cat"12"dog"23"cat"34"bird"4
#
#
#
#
#
# print("Số phần tử trong danh sách là:", count)
# → Sau khi vòng lặp kết thúc, chương trình in ra giá trị cuối cùng của count.
# Kết quả sẽ là:
# Số phần tử trong danh sách là: 4
#
#
#
#
# ✅ Kết luận:
#
#
# Công việc của đoạn code:
# Đếm số lượng phần tử có trong danh sách animals.
#
#
# Kết quả in ra:
# Số phần tử trong danh sách là: 4
#
#
#
#
# Khi thực thi trong Python:
# Kết quả thực tế hoàn toàn trùng khớp với phân tích:
# Số phần tử trong danh sách là: 4

# %%
animals = ["cat", "dog", "cat", "bird"]
count = 0
for a in animals:
    count += 1
print("Số phần tử trong danh sách là:", count)
# Out:
# Số phần tử trong danh sách là: 4

# %% [markdown]
# 1) Tổng quan — chương trình đang làm gì
#
# Chương trình là một menu đơn giản cho phép người dùng chọn một trong ba chức năng:
#
# 1) Sentiment analysis — phân tích cảm xúc của một đoạn văn (ví dụ: positive/negative/neutral).
#
# 2) Weather forecast — trả về dự báo thời tiết cho một vị trí/ngày nhất định.
#
# 3) Exit — thoát chương trình.
#
# Sau khi người dùng chọn một mục (ví dụ gõ 1), chương trình sẽ thực hiện bước tương ứng: yêu cầu thêm dữ liệu (ví dụ: đoạn văn hoặc địa điểm), chạy mô-đun xử lý (mô hình NLP hoặc gọi API thời tiết), rồi in kết quả ra màn hình.
#
# 2) Luồng xử lý (flow) cơ bản
#
# Hiển thị menu.
#
# Đọc lựa chọn của người dùng.
#
# Nếu chọn 1:
#
# Yêu cầu nhập văn bản.
#
# Gửi văn bản vào bộ phân tích cảm xúc (có thể là rule-based, lexicon-based, hoặc ML/DL).
#
# In nhãn (ví dụ: Positive, Negative, Neutral) và điểm/confidence nếu có.
#
# Nếu chọn 2:
#
# Yêu cầu nhập địa điểm (city, zip, lat/long) và có thể ngày.
#
# Gọi API thời tiết hoặc module nội bộ để lấy dữ liệu.
#
# Hiển thị nhiệt độ, trạng thái (mưa/nắng), khả năng mưa, v.v.
#
# Nếu chọn 3: thoát.
#
# 3) Vì sao chương trình cho kết quả như vậy — nguyên nhân kỹ thuật
# A. Sentiment analysis — tại sao kết quả có thể là positive/negative/neutral
#
# Kiến trúc/mô hình: Nếu dùng mô hình học máy (logistic regression, SVM, neural net, Transformer), kết quả phụ thuộc vào dữ liệu huấn luyện. Mô hình học cách liên kết từ/biểu thức với nhãn cảm xúc dựa trên mẫu trong dữ liệu.
#
# Từ vựng & ngữ cảnh: Từ đơn lẻ có thể thay đổi nghĩa theo ngữ cảnh. Ví dụ "sick" có thể là tiêu cực (bệnh) hoặc tích cực (slang: "rất hay"). Nếu mô hình không bắt được ngữ cảnh, kết quả sai.
#
# Phủ định / Negation: Câu "I don't like this" có từ "like" (thường positive) nhưng có phủ định; nếu bộ xử lý không nhận phủ định, nó có thể dự đoán sai.
#
# Sarkasm / Irony: Mô hình thường gặp khó với mỉa mai, trừ khi được huấn luyện nhiều ví dụ tương tự.
#
# Độ tin cậy (confidence): Nhiều hệ thống trả cả nhãn và điểm xác suất; điểm thấp nghĩa mô hình “không chắc”.
#
# Tiếng & mã hóa: Nếu văn bản có emoji, lỗi mã hóa, hay tiếng Việt có dấu/không dấu, chất lượng giảm nếu pipeline không chuẩn hoá tốt.
#
# B. Weather forecast — tại sao dự báo như vậy
#
# Nguồn dữ liệu: Kết quả phụ thuộc vào nguồn (API: OpenWeather, MET, v.v. hoặc mô hình nội bộ). Khác nguồn = khác dự báo.
#
# Mô hình dự báo: Thời tiết dựa trên mô hình vật lý/biên dịch số (numerical weather prediction) — chúng cho ra xác suất (ví dụ: 60% mưa). Không phải là chắc chắn 100%.
#
# Độ phân giải không gian & thời gian: Dự báo cho một thành phố lớn có thể trung bình nhiều vị trí; microclimate (một khu vực nhỏ) có thể khác.
#
# Cập nhật dữ liệu: Nếu chương trình dùng dữ liệu cũ (cache) hoặc API bị lỗi, kết quả có thể không hợp thời.
#
# Thời điểm dự báo: Dự báo ngắn hạn (24–72h) thường chính xác hơn so với dự báo dài hạn.
#
# 4) Ví dụ minh họa (kết quả mẫu)
#
# Sentiment:
#
# Input: "I love this product!" → Output: Positive (0.95)
#
# Input: "Not bad, could be better." → Output: Neutral (0.60) hoặc Positive tùy model
#
# Input: "Great... just what I didn't need." (mỉa mai) → Model đơn giản có thể nhầm là Positive.
#
# Weather:
#
# Input: Hanoi, 2025-11-08 → Output: High 30°C, Low 24°C, 20% chance of rain (ví dụ).
#
# Nếu API trả về lỗi: chương trình có thể in Unable to fetch weather.
#
# 5) Những nguyên nhân điển hình khiến kết quả sai/mơ hồ và cách khắc phục
#
# Vấn đề: Văn bản chứa ngôn ngữ hỗn hợp, emoji, lỗi gõ.
#
# Khắc phục: Tiền xử lý (normalize, remove noise), hỗ trợ emoji và slang.
#
# Vấn đề: Mô hình thiếu dữ liệu cho ngôn ngữ cụ thể (ví dụ: tiếng Việt).
#
# Khắc phục: Huấn luyện mô hình trên dữ liệu ngôn ngữ mục tiêu; dùng embedding pre-trained (BERT multilingual, PhoBERT cho tiếng Việt).
#
# Vấn đề: Không xử lý phủ định / câu phức tạp.
#
# Khắc phục: Thêm bước dependency parsing hoặc features cho phủ định, bigrams/trigrams.
#
# Vấn đề: Weather API rate limit / offline.
#
# Khắc phục: Cache có thời hạn, fallback message rõ ràng (e.g., “Không thể truy vấn API, thử lại sau”).
#
# Vấn đề: Kết quả không có giải thích (black-box).
#
# Khắc phục: Trả thêm thông tin giải thích — top contributing words, hoặc saliency map, hoặc confidence score.
#
# 6) Gợi ý cải tiến (kỹ thuật & UX)
#
# Sentiment
#
# Dùng mô hình Transformer fine-tuned (ví dụ BERT / RoBERTa / PhoBERT cho tiếng Việt).
#
# Trả về confidence score và highlight các từ góp phần lớn vào quyết định.
#
# Bổ sung xử lý sarcasm bằng training với dữ liệu có mỉa mai nếu cần.
#
# Weather
#
# Hiện thị timestamp của dữ liệu (khi nào cập nhật).
#
# Hiển thị xác suất và nguồn dữ liệu (ví dụ: OpenWeatherMap).
#
# Cho phép nhập vị trí theo GPS hoặc tên thành phố + tùy chọn đơn vị (°C/°F).
#
# UX
#
# Kiểm tra input hợp lệ, thêm hướng dẫn (ví dụ: nhập 1, 2, hoặc 3).
#
# Thêm menu con (ví dụ: trong sentiment cho phép chọn ngôn ngữ).
#
# 7) Lưu ý về bảo mật và quyền riêng tư
#
# Nếu gửi văn bản người dùng lên API bên thứ ba (sentiment hoặc weather), thông tin nhạy cảm có thể bị lộ. Thông báo cho người dùng về privacy.
#
# Lưu log: nếu lưu trữ logs nội dung, cần mã hoá và tuân thủ luật bảo mật dữ liệu.

# %%
=== AI Prediction System ===
1) Sentiment analysis
2) Weather forecast
3) Exit
Please choose an option:
# Out:
#   Cell In[9], line 2
#     1) Sentiment analysis
#      ^
# SyntaxError: unmatched ')'

# %% [markdown]
# input() trả về chuỗi — cần dùng int() để chuyển sang số nguyên trước khi làm phép %.
#
# Trong if num % 2 = 0: dùng = là phép gán, phải dùng phép so sánh ==.
#
# Thiếu dấu : sau if và else.
#
# Thiếu thụt lề cho các lệnh bên trong if/else (Python yêu cầu).
#
# (Tùy chọn) Thêm try/except để xử lý trường hợp người dùng nhập không phải số nguyên.

# %%
try:
    num = int(input("Nhập số: "))
    if num % 2 == 0:
        print("Số chẵn")
    else:
        print("Số lẻ")
except ValueError:
    print("Vui lòng nhập một số nguyên hợp lệ.")
# Out:
# Số lẻ

# %% [markdown]
# Giải thích chi tiết:
#
# range(3) tạo ra một dãy số:
#
# 0, 1, 2
#
#
# (tức là lặp 3 lần).
#
# Trong mỗi vòng lặp, biến i lần lượt có giá trị 0 → 1 → 2.
#
# Lệnh bên trong vòng lặp:
#
# print("AI đang học lần", i + 1)
#
#
# Mỗi lần in ra số lần học, ta cộng 1 vì i bắt đầu từ 0.
#
# Sau khi vòng lặp kết thúc (chạy xong 3 lần), lệnh:
#
# print("Huấn luyện xong!")
#
#
# được thực hiện một lần duy nhất (vì không thụt vào trong for).
#
# 💡 Kết quả in ra (output)
# AI đang học lần 1
# AI đang học lần 2
# AI đang học lần 3
# Huấn luyện xong!
#
# 🧩 Giải thích “vì sao”
#
# Python chạy vòng lặp for i in range(3) → i lần lượt là 0, 1, 2 → chạy 3 lần.
#
# Mỗi lần, nó in thông báo "AI đang học lần <số>".
#
# Sau khi thoát vòng lặp, lệnh cuối "Huấn luyện xong!" chỉ chạy một lần duy nhất.
#
# Nếu dòng print("Huấn luyện xong!") được thụt vào trong vòng lặp, như thế này:
#
# for i in range(3):
#     print("AI đang học lần", i + 1)
#     print("Huấn luyện xong!")
#
#
# thì kết quả sẽ là:
#
# AI đang học lần 1
# Huấn luyện xong!
# AI đang học lần 2
# Huấn luyện xong!
# AI đang học lần 3
# Huấn luyện xong!
#
#
# 👉 Vì cả hai lệnh đều nằm trong vòng lặp, nên chúng được lặp lại 3 lần.

# %%
for i in range(3):
    print("AI đang học lần", i + 1)
    print("Huấn luyện xong!")
# Out:
# AI đang học lần 1
# Huấn luyện xong!
# AI đang học lần 2
# Huấn luyện xong!
# AI đang học lần 3
# Huấn luyện xong!

# %% [markdown]
# 🧠 Giải thích từng phần:
#
# ["cat", "dog", "fish"] là một danh sách (list) gồm 3 chuỗi:
#
# "cat"
#
# "dog"
#
# "fish"
#
# for x in ["cat", "dog", "fish"]: nghĩa là:
#
# Lặp qua từng phần tử trong danh sách.
#
# Mỗi lần lặp, biến x sẽ lấy giá trị của phần tử hiện tại.
#
# Lệnh bên trong vòng lặp:
#
# print("Dự đoán con vật:", x)
#
#
# sẽ in ra một dòng chứa chuỗi "Dự đoán con vật:" và giá trị của x.
#
# 💡 Kết quả in ra (output)
#
# Vì danh sách có 3 phần tử, vòng lặp chạy 3 lần, nên chương trình in ra 3 dòng:
#
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish
#
# 🧩 Giải thích “vì sao”
#
# Vòng lặp for duyệt qua từng phần tử trong list.
#
# Mỗi lần, nó in một dòng mới.
#
# Tổng cộng danh sách có 3 phần tử ⇒ in ra 3 dòng tương ứng.
#
# ✅ Tóm lại:
#
# Số dòng in ra: 3
#
# Nội dung in ra:
#
# Dự đoán con vật: cat
#
# Dự đoán con vật: dog
#
# Dự đoán con vật: fish

# %%
for x in ["cat", "dog", "fish"]:
    print("Dự đoán con vật:", x)
# Out:
# Dự đoán con vật: cat
# Dự đoán con vật: dog
# Dự đoán con vật: fish

# %% [markdown]
# 🧠 Phân tích lỗi cú pháp (Syntax Errors)
# Dòng	Lỗi	Giải thích
# print "=== AI Prediction System ==="	❌ Thiếu ngoặc tròn	Python 3 yêu cầu dùng print() có ngoặc
# print("1) Sentiment analysis"	❌ Thiếu dấu ngoặc đóng )	Hàm print() phải có cặp ngoặc đủ
# print("2) Weather forecast"))	❌ Dư 1 dấu ngoặc )	Có 3 ngoặc đóng nhưng chỉ 2 mở
# print('3) Exit'	❌ Thiếu ngoặc đóng )	Cần print('3) Exit')
# Toàn bộ chương trình	⚠️ Không có lỗi logic, chỉ lỗi cú pháp	Sau khi sửa, code chạy đúng
# ✅ Phiên bản đã sửa đúng cú pháp (chuẩn Python 3)
# # Simple menu
# print("=== AI Prediction System ===")
# print("1) Sentiment analysis")
# print("2) Weather forecast")
# print("3) Exit")
# print("Please choose an option:")
#
# 💡 Kết quả in ra khi chạy
# === AI Prediction System ===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit
# Please choose an option:
#
#
# Tóm lại:
#
# ✅ Sửa tất cả lỗi ngoặc tròn ((, ))
#
# ✅ Dùng cú pháp print() của Python 3
#
# ✅ Thêm ngoặc đúng chỗ để tránh lỗi SyntaxError

# %%
print("=== AI Prediction System ===")
print("1) Sentiment analysis")
print("2) Weather forecast")
print("3) Exit")
print("Please choose an option:")
# Out:
# === AI Prediction System ===
# 1) Sentiment analysis
# 2) Weather forecast
# 3) Exit
# Please choose an option:
