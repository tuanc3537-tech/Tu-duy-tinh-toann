# %%
a=22
b=55
a= a^b
b= a^b
a= a^b
print(a, b)
# Out:
# 55 22

# %%
n = int(input())
if n>0 and (n & (n-1))==0:
    print("n la luy thua cua 2 ")
else:
    print("n k phai la luy thua cua 2")
# Out:
# n la luy thua cua 2

# %%
import math
m, n = map(float, input().split())
d=m/n
print(math.floor(d))
# Out:
# 0

# %%
import math
m, n = map(float, input().split())
d=m/n
print(math.ceil(d))
# Out:
# 1

# %%
x = float(input())
if x%2==0:
    print("even")
else:
    print("odd")
# Out:
# even

# %%
a =int(input())
b= int(input())
if a<0 and b<0:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
a = input()
b = input()
if len(a)>len(b):
    print("true")
else:
    print("false")
# Out:
# true

# %%
a, b, c = map(float, input().split())
if a+b<=c or a+c<=b or b+c<=a:
    print("no")
else:
    print("yes")
# Out:
# yes

# %%
a, b, c, d = map(int, input().split())
print(max(a, b, c, d))
# Out:
# 7

# %%
a, b, c = map(float, input().split())
if a+b<=c or a+c<=b or b+c<=a:
    print("khong phai la 3 canh tam giac")
elif a==b or b==c or a==c:
    print("la tam giac can")
elif a==b and a==c and b==c:
    print("la tam giac deu")
elif a**2==b**2 + c**2 or b**2==a**2 + c**2 or c**2== a**2+b**2 :
    print("la tam giac vuong")
else:
    print("la tam giac thuong")
# Out:
# la tam giac thuong

# %%
x = int(input())
if x%4==0 and x%100!=0 or x%400==0:
    print("yes")
else:
    print("no")
# Out:
# no

# %%
a=float(input())
if a>= 8:
    print("gioi")
elif 6.5<=a<=8:
    print('kha')
elif 5<=a<=6.5:
    print("trung binh")
else:
    print("yeu")
# Out:
# kha

# %%
a = float(input())
n = int(a)
ceil = n if a == n else (n+1 if a>0 else n)
floor = n if a >= 0 else (n if a == n else n-1)
nearest = n if abs(a-n) < 0.5 else (n+1 if a>0 else n-1)
print(ceil, floor, nearest)
# Out:
# -1 -2 -2

# %%
a, b, c, d=map(float, input().split())
if a!=0 and b%a==0:
    r=b/a
    if c==b*r and d==c*r:
        print("la cap so nhan")
    else:
        print("khong phai cap so nhan")
else:
    print("khong phai cap so nhan")
# Out:
# la cap so nhan
