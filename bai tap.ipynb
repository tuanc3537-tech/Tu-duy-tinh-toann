# %%
a = int(input(10))
b = int(input(20))
tong = a+b
hieu = a-b
tich = a*b
phan_nguyen = a//b
phan_du = a%b
phan_thuc = a/b
print("Tong:", tong)
print("Hieu:", hieu)
print("Tich:", tich)
print("Phan Nguyen", phan_nguyen)
print("phan du", phan_du)
print("phan thuc: {:.2f}".format(phan_thuc))
# Out:
# Tong: 30
# Hieu: -10
# Tich: 200
# Phan Nguyen 0
# phan du 10
# phan thuc: 0.50

# %%
a1, a2, a3, b1, b2, c1 = map(float, input().split())
TB= ((a1+b1+c1)+(b2+a2)*2+a3*3)/10
print(f"{TB:.1f}")
# Out:
# 5.6

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
name =input("Cao Huy Tuan")
print(name)

# %%
a = int(input(10))
b = int(input(2))
c = a**b
print(c)
# Out:
# 100

# %%
a = input("(a-z):")
print(ord(a))
b = chr(ord(a)-23)
print(b)
# Out:
# 99
# L

# %%
C = 36
F = 9/5*C + 32
print("nhiet do {:.2f}".format(F))
# Out:
# nhiet do 96.80

# %%
X = int(input())
Thuc = X*140/100
print("tien : {:.2f}".format(Thuc))
# Out:
# tien : 729700376385.40

# %%
names = input()
name_list = names.split()
name_list.reverse()
print(f"{name_list[0]}, {name_list[1]} and {name_list[2]}.")
# Out:
# Trai, Dep and Tuan.

# %%
a = int(input())
m = a**2*6
print(m)
# Out:
# 24

# %%
a = int(input())
b = int(input())
h = (a*b)%10
print(h)
# Out:
# 0

# %%
H = int(input("10"))
P = int(input("50"))
S = H * 3600
SE = P * 60 
tong = S + SE
print("Tổng số giây là:", tong)
# Out:
# Tổng số giây là: 39000

# %%
a = 10
b = 2
a ,b = b, a
print(a)
print(b)
# Out:
# 2
# 10

# %%
a = int(input())
so_sao = 6*(a-1)*a+1
print(so_sao)
# Out:
# 121

# %%
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
print("  *")
print(" ***")
print("*****")
# Out:
#   *
#  ***
# *****

# %%
print("### # #   ### ###")
print(" #  #   #  #   #")
print(" #  #    # #   #")
print(" #  #   #  #   #")
print(" #  #  #   #   #")
# Out:
# ### # #   ### ###
#  #  #   #  #   #
#  #  #    # #   #
#  #  #   #  #   #
#  #  #  #   #   #

# %%
print("""
Monday
Tuesday
Wednesday
Thursday
Friday
Saturday
Sunday
""")
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
print("""
January
February
March
April
May
June
July
August
September
""")
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
